# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohithkr02/nlpproject/blob/main/glovetwitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\unais\Desktop\nlpproject\nlpproject\redditpreprocess.csv")
df
# Out:
#         post_id                                               text label_adr
# 0        8zr5u3  Ive always chewed nail never knew anxiety alwa...  withdraw
# 1    8zr5u3_aug  Ive always chewed nail never knew anxiety alwa...  withdraw
# 2    8zr5u3_aug  Ive always chewed nail never knew anxiety alwa...  withdraw
# 3    8zr5u3_aug  Ive always chewed nail never knew anxiety anxi...  withdraw
# 4        8zgg5h  Ive Effexor XR 8 year started 75mg 4 year ago ...  withdraw
# ..          ...                                                ...       ...
# 751  8zbap8_aug  taking Cipralex almost two year bumped 20mg fo...  withdraw
# 752      8y7dy7  Ive struggling anxiety depression basically lo...  withdraw
# 753  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
# 754  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
# 755  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
#
# [756 rows x 3 columns]

# %%
import gensim.downloader as api
import numpy as np
wv = api.load('glove-twitter-100')
# Out:
# [==================================================] 100.0% 387.1/387.1MB downloaded

# %%
df['text'] = df['text'].apply(lambda x: np.mean([wv[token] for token in x if token in wv] or [np.zeros(wv.vector_size)], axis=0))

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['label_adr'] = label_encoder.fit_transform(df['label_adr'])

# %%
import numpy as np
X = np.vstack(df['text'])  # Convert list of arrays to a matrix
y = df['label_adr']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.svm import SVC
#from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
rr=SVC()
#dt=MultinomialNB()
rd=DecisionTreeClassifier()
rf=RandomForestClassifier()
lst=[rr,rd,rf]
for i in lst:
  i.fit(X_train,y_train)
  y_pred1=i.predict(X_test)
  print('**************')
  print('**************')
  print(classification_report(y_test,y_pred1))
# Out:
# **************
# **************
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.00      0.00      0.00        13
#            2       0.00      0.00      0.00        17
#            3       0.00      0.00      0.00        14
#            4       0.00      0.00      0.00        11
#            5       0.00      0.00      0.00        12
#            6       0.00      0.00      0.00        14
#            7       0.32      1.00      0.49        49
#
#     accuracy                           0.32       152
#    macro avg       0.04      0.12      0.06       152
# weighted avg       0.10      0.32      0.16       152
#
# **************
# **************
#               precision    recall  f1-score   support
#
#            0       0.65      0.68      0.67        22
#            1       0.30      0.23      0.26        13
#            2       0.61      0.65      0.63        17
# ...
