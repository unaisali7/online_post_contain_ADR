# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohithkr02/nlpproject/blob/main/tfidfvectorizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/redditpreprocess.csv")
df
# Out:
#         post_id                                               text label_adr
# 0        8zr5u3  Ive always chewed nail never knew anxiety alwa...  withdraw
# 1    8zr5u3_aug  Ive always chewed nail never knew anxiety alwa...  withdraw
# 2    8zr5u3_aug  Ive always chewed nail never knew anxiety alwa...  withdraw
# 3    8zr5u3_aug  Ive always chewed nail never knew anxiety anxi...  withdraw
# 4        8zgg5h  Ive Effexor XR 8 year started 75mg 4 year ago ...  withdraw
# ..          ...                                                ...       ...
# 751  8zbap8_aug  taking Cipralex almost two year bumped 20mg fo...  withdraw
# 752      8y7dy7  Ive struggling anxiety depression basically lo...  withdraw
# 753  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
# 754  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
# 755  8y7dy7_aug  Ive struggling anxiety depression basically lo...  withdraw
#
# [756 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['label_adr'] = label_encoder.fit_transform(df['label_adr'])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer()
txt=tfidf.fit_transform(df.text)

# %%
X=txt
y=df['label_adr']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
rr=SVC()
dt=MultinomialNB()
rd=DecisionTreeClassifier()
rf=RandomForestClassifier()
lst=[rr,dt,rd,rf]
for i in lst:
  i.fit(X_train,y_train)
  y_pred1=i.predict(X_test)
  print('**************')
  print('**************')
  print(classification_report(y_test,y_pred1))
# Out:
# **************
# **************
#               precision    recall  f1-score   support
#
#            0       0.75      0.55      0.63        22
#            1       0.29      0.15      0.20        13
#            2       0.67      0.59      0.62        17
#            3       0.56      0.71      0.63        14
#            4       1.00      0.45      0.62        11
#            5       1.00      0.33      0.50        12
#            6       0.68      0.93      0.79        14
#            7       0.51      0.71      0.60        49
#
#     accuracy                           0.60       152
#    macro avg       0.68      0.55      0.57       152
# weighted avg       0.64      0.60      0.59       152
#
# **************
# **************
#               precision    recall  f1-score   support
#
#            0       1.00      0.23      0.37        22
#            1       0.00      0.00      0.00        13
#            2       0.71      0.29      0.42        17
# ...
